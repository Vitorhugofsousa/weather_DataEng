# %%
path = '../data/weather_data.json'

import pandas as pd
# Out:
# O kernel falhou ao iniciar porque o ambiente do Python “weather_DataEng (3.12.3) (Python 3.12.3)” não está mais disponível. Considere selecionar outro kernel ou atualizar a lista de Ambientes do Python.
